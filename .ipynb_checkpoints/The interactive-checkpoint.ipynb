# %%
noun = input("Enter your noun")
verb = input("Enter your verb")
adjective = input("Enter your adjective")
place = input("Enter your place")

story = f" One day,a {adjective} {noun}  {verb} to {place}."
print("----------------------------------------------")
print(story)
# Out:
# Enter your noun cat
# Enter your verb go
# Enter your adjective big
# Enter your place school
# ----------------------------------------------
#  One day,a big cat  go to school.
